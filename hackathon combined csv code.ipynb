# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
file1 = r"C:\Users\JAHNAVI\Downloads\financial transactions\budgetwise_finance_dataset.csv"
file2 = r"C:\Users\JAHNAVI\Downloads\financial transactions\budgetwise_synthetic_dirty.csv"

# %%
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# %%
combined_df = pd.concat([df1, df2], ignore_index=True)

# %%
combined_df.to_csv(r"C:\Users\JAHNAVI\Downloads\financial transactions\budget_dataset.csv", index=False)
combined_df.to_csv(r"C:\Users\JAHNAVI\Documents\finance_categorization_project\budget_dataset.csv", index=False)

print("CSV files combined successfully")
# Out:
# CSV files combined successfully
